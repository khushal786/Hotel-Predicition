# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as  sn

# %%
df = pd.read_csv(r"C:\Users\khush\OneDrive\Desktop\DataSets\Hotels.csv")

# %%
df.head()
# Out:
#    Unnamed: 0   Location            Unnamed: 2  Rating  Number of Ratings  \
# 0           0  Hyderabad    1. Deccan Pavilion     5.0                953
# 1           1  Hyderabad  2. Dum Pukht Begum's     5.0                478
# 2           2      Patna            3. Dominos     4.0                 99
# 3           3      Patna     4. Mainland China     4.5                119
# 4           4     Mumbai      2. Delhi Highway     5.0                 83
#
#                Cuisine
# 0        Indian, Asian
# 1               Indian
# 2     Pizza, Fast food
# 3       Chinese, Asian
# 4  Indian, Street Food

# %%
df.describe()
# Out:
#        Unnamed: 0     Rating  Number of Ratings
# count    10.00000  10.000000          10.000000
# mean      4.50000   4.850000         302.200000
# std       3.02765   0.337474         281.532631
# min       0.00000   4.000000          83.000000
# 25%       2.25000   5.000000         104.000000
# 50%       4.50000   5.000000         156.500000
# 75%       6.75000   5.000000         456.500000
# max       9.00000   5.000000         953.000000

# %%
plt.bar(df['Rating'], df['Number of Ratings'])
plt.xlabel("Rating")
plt.ylabel("Number of Ratings")
plt.title("Rating vs Review")
plt.xticks(rotation=45)
plt.show()

# %%
plt.bar(df['Cuisine'], df['Rating'])
plt.xlabel("Cuisine")
plt.ylabel("Rating")
plt.title("Cuisine vs Rating")
plt.xticks(rotation=45)
plt.show()

# %%
plt.scatter(df['Location'], df['Cuisine'])
plt.xlabel("Location")
plt.ylabel("Cuisine")
plt.title("Location vs. Cuisine")
plt.show()

# %%
plt.scatter(df['Rating'], df['Location'])
plt.xlabel("Rating")
plt.ylabel("Location")
plt.title("Rating vs. Location")
plt.show()
